# %% [markdown]
# Questions on data...
#
# Number of property types: 15(in property_type column in csv file)
# Names of property types:
# ['Apartment' nan 'Duplex' 'Mixed' 'Ground' 'Penthouse' 'Bungalow' 'Chalet'
#  'Loft' 'Mansion' 'Master' 'Residence' 'Cottage' 'Studio' 'Triplex'
#  'Villa']
# Q1. Are we going to keep these types like they are or are we going to rename them? Like to say apartment, house and ground (3types) and to rename others to be in the category of apartment, house and ground?
#
#
#
# Price per square-meter for the living_area for each property?
# Q2. Are we going to need this info to calculate and add it to the data?
